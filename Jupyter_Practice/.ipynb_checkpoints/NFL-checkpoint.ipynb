# %%
# Practice getting NFL data and making data tables

# %%
from sportsipy.nfl.schedule import Schedule
from sportsipy.nfl.teams import Teams
import pandas as pd
from sportsipy.nfl.boxscore import Boxscores, Boxscore
from datetime import date
import requests
from bs4 import BeautifulSoup
import re
import keras
import seaborn as sns
import sports

# %%
football = sports.get_sport('football')
nfl = football.all_matches()
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in close(self)
#    1726         try:
# -> 1727             self.parser.Parse(b"", True) # end of data
#    1728         except self._error as v:
#
# ExpatError: no element found: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# ParseError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _request_xml(sport)
#      44         r = requests.get(url)
# ---> 45         return _load_xml(r.content)
#      46     except ET.ParseError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _load_xml(xml_data)
#      58     """
# ---> 59     return ET.fromstring(xml_data).find('channel').findall('item')
#      60
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\defusedxml\common.py in fromstring(text, forbid_dtd, forbid_entities, forbid_external)
#     126         parser.feed(text)
# --> 127         return parser.close()
#     128
#
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in close(self)
#    1728         except self._error as v:
# -> 1729             self._raiseerror(v)
#    1730         try:
#
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in _raiseerror(self, value)
#    1628         err.position = value.lineno, value.offset
# -> 1629         raise err
#    1630
#
# ParseError: no element found: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# SportError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39172/939028886.py in <module>
# ----> 1 all_matches = sports.all_matches()
#       2 nfl = all_matches['football']
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in all_matches()
#     169     :rtype: dict
#     170     """
# --> 171     return {sport: get_sport(sport) for sport in constants.SPORTS}
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in <dictcomp>(.0)
#     169     :rtype: dict
#     170     """
# --> 171     return {sport: get_sport(sport) for sport in constants.SPORTS}
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in get_sport(sport)
#     104     """
#     105     sport = sport.lower()
# --> 106     data = _request_xml(sport)
#     107
#     108     cricket_regex = re.compile(r'\(([^)]+)\) #(.+) vs #(.+): ([\d/]+\s\([^)]+\))? ?- ([\d/]+\s\([^)]+\))?')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _request_xml(sport)
#      45         return _load_xml(r.content)
#      46     except ET.ParseError:
# ---> 47         raise errors.SportError(sport)
#      48
#      49
#
# SportError: Sport not found for baseball

# %%
teams = Teams()
df = pd.DataFrame(columns = ['Name', 'Abbreviation', 'Penalties', 'Wins', 'Pass Attempts', 'Rush Attempts', 'First Downs',
                            'Turnovers', 'Strength of Schedule', 'Rushing Yards', 'Passing Yards', 'Fumbles', 'Interceptions'])

df['Name'] = [x.name for x in teams]
df['Abbreviation'] = [x.abbreviation for x in teams]
df['Wins'] = [x.wins for x in teams]
df['Penalties'] = [x.penalties for x in teams]
df['Pass Attempts'] = [x.pass_attempts for x in teams]
df['Rush Attempts'] = [x.rush_attempts for x in teams]
df['First Downs'] = [x.first_downs for x in teams]
df['Turnovers'] = [x.turnovers for x in teams]
df['Strength of Schedule'] = [x.strength_of_schedule for x in teams]
df['Rushing Yards'] = [x.rush_yards for x in teams]
df['Passing Yards'] = [x.pass_yards for x in teams]
df['Fumbles'] = [x.fumbles for x in teams]
df['Interceptions'] = [x.interceptions for x in teams]

# %%
correlation_data = df[['Wins', 'Pass Attempts', 'Rush Attempts', 'Penalties', 'Turnovers', 'First Downs', 'Strength of Schedule',
                  'Rushing Yards', 'Passing Yards', 'Fumbles', 'Interceptions']]
correlation_data.corr(method ='pearson')
# Out:
#                           Wins  Pass Attempts  Rush Attempts  Penalties  \
# Wins                  1.000000       0.130542       0.387813  -0.207260
# Pass Attempts         0.130542       1.000000      -0.599684   0.378612
# Rush Attempts         0.387813      -0.599684       1.000000  -0.147973
# Penalties            -0.207260       0.378612      -0.147973   1.000000
# Turnovers            -0.386065       0.191683      -0.132475   0.209766
# First Downs           0.771425       0.409033       0.322571   0.064926
# Strength of Schedule -0.253977       0.215623      -0.306096   0.415069
# Rushing Yards         0.316449      -0.510704       0.865226  -0.090717
# Passing Yards         0.622941       0.720027      -0.287043   0.155330
# Fumbles              -0.192806       0.077732      -0.017250   0.054437
# Interceptions        -0.336476       0.177294      -0.143266   0.211432
#
#                       Turnovers  First Downs  Strength of Schedule  \
# Wins                  -0.386065     0.771425             -0.253977
# Pass Attempts          0.191683     0.409033              0.215623
# Rush Attempts         -0.132475     0.322571             -0.306096
# Penalties              0.209766     0.064926              0.415069
# Turnovers              1.000000    -0.140010              0.161194
# First Downs           -0.140010     1.000000             -0.124913
# Strength of Schedule   0.161194    -0.124913              1.000000
# Rushing Yards         -0.203651     0.441557             -0.266268
# Passing Yards         -0.215962     0.682122             -0.011678
# Fumbles                0.501089    -0.017504              0.060149
# Interceptions          0.870602    -0.151828              0.152061
#
#                       Rushing Yards  Passing Yards   Fumbles  Interceptions
# Wins                       0.316449       0.622941 -0.192806      -0.336476
# Pass Attempts             -0.510704       0.720027  0.077732       0.177294
# Rush Attempts              0.865226      -0.287043 -0.017250      -0.143266
# Penalties                 -0.090717       0.155330  0.054437       0.211432
# Turnovers                 -0.203651      -0.215962  0.501089       0.870602
# First Downs                0.441557       0.682122 -0.017504      -0.151828
# Strength of Schedule      -0.266268      -0.011678  0.060149       0.152061
# Rushing Yards              1.000000      -0.228887  0.031351      -0.253137
# Passing Yards             -0.228887       1.000000 -0.166603      -0.154824
# Fumbles                    0.031351      -0.166603  1.000000       0.010485
# Interceptions             -0.253137      -0.154824  0.010485       1.000000

# %%
sns.heatmap(correlation_data.corr(), annot=True, cmap="mako")
# Out:
# <AxesSubplot:>

# %%
# creating the date object of today's date
todays_date = date.today()

# web scrape CBS for current week
url = 'https://www.cbssports.com/nfl/schedule/'
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find(id="PageTitle-header").text
try:
    current_week = int(re.search(r'\d+', results).group())
except:
    print('Not in season')

games_today = Boxscores(current_week, todays_date.year)
# Prints a dictionary of all matchups for week 1 of 2017
# games_today = pd.DataFrame.from_dict(games_today.games)

# %%
current_schedule = pd.DataFrame(columns = ['Away Team', 'Home Team', 'Away Score', 'Home Score', 'Winner'])

# %%
game_date = []

for key in games_today.games.keys():
        current_schedule['Away Team'] =  [item['away_name'] for item in games_today.games[key]]
        current_schedule['Home Team'] =  [item['home_name'] for item in games_today.games[key]]
        current_schedule['Away Score'] =  [item['away_score'] for item in games_today.games[key]]
        current_schedule['Home Score'] =  [item['home_score'] for item in games_today.games[key]]
        current_schedule['Winner'] =  [item['winning_name'] for item in games_today.games[key]]
        game_date.extend(item['boxscore'] for item in games_today.games[key])

# %%
print(game_date) 

for i in range(len(game_date)):
    game_info = Boxscore(i)
    game_date[i] = game_info.date
    
print(game_date)
# Out:
# ['202112160sdg', '202112180cle', '202112180clt', '202112190rav', '202112190pit', '202112190phi', '202112190nyg', '202112190mia', '202112190jax', '202112190det', '202112190buf', '202112190sfo', '202112190den', '202112190ram', '202112190tam', '202112200chi']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
history_of_seasons = pd.DataFrame(columns = ['Away Team', 'Home Team', 'Away Score', 'Home Score', 'Winner'])

# %%
year = todays_date.year
week = current_week-1
away = []
home = []
away_score = []
home_score = []
winner = []

while year >= todays_date.year-5:
    if year != todays_date.year: week = 16
    while week >= 1:
        previous_games = Boxscores(week, year)
        for key in previous_games.games.keys():
            away.extend(item['away_name'] for item in previous_games.games[key])
            home.extend(item['home_name'] for item in previous_games.games[key])
            away_score.extend(item['away_score'] for item in previous_games.games[key])
            home_score.extend(item['home_score'] for item in previous_games.games[key])
            winner.extend(item['winning_name'] for item in previous_games.games[key])
        week = week-1 
    year = year-1

# %%
history_of_seasons['Away Team'] =  away
history_of_seasons['Home Team'] =  home
history_of_seasons['Away Score'] = away_score
history_of_seasons['Home Score'] =  home_score
history_of_seasons['Winner'] =  winner

# %%
#history_of_seasons=history_of_seasons.replace({'Oakland Raiders': 'Las Vegas Raiders', 'St. Louis Rams':'Los Angeles Rams',
#                           'Washington Redskins':'Washington Football Team'}, regex=True)

# %%
history_of_seasons
# Out:
#                  Away Team                 Home Team  Away Score  Home Score  \
# 0      Pittsburgh Steelers         Minnesota Vikings          28          36
# 1      San Francisco 49ers        Cincinnati Bengals          26          23
# 2          Atlanta Falcons         Carolina Panthers          29          21
# 3           Dallas Cowboys  Washington Football Team          27          20
# 4     Jacksonville Jaguars          Tennessee Titans           0          20
# ...                    ...                       ...         ...         ...
# 1403         Detroit Lions        Indianapolis Colts          39          35
# 1404       New York Giants            Dallas Cowboys          20          19
# 1405  New England Patriots         Arizona Cardinals          23          21
# 1406   Pittsburgh Steelers  Washington Football Team          38          16
# 1407      Los Angeles Rams       San Francisco 49ers           0          28
#
#                     Winner
# 0        Minnesota Vikings
# 1      San Francisco 49ers
# 2          Atlanta Falcons
# 3           Dallas Cowboys
# 4         Tennessee Titans
# ...                    ...
# 1403         Detroit Lions
# 1404       New York Giants
# 1405  New England Patriots
# 1406   Pittsburgh Steelers
# 1407   San Francisco 49ers
#
# [1408 rows x 5 columns]

# %%
all_matches = sports.all_matches()
nfl = all_matches['football']
# Out:
# ---------------------------------------------------------------------------
# ExpatError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in close(self)
#    1726         try:
# -> 1727             self.parser.Parse(b"", True) # end of data
#    1728         except self._error as v:
#
# ExpatError: no element found: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# ParseError                                Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _request_xml(sport)
#      44         r = requests.get(url)
# ---> 45         return _load_xml(r.content)
#      46     except ET.ParseError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _load_xml(xml_data)
#      58     """
# ---> 59     return ET.fromstring(xml_data).find('channel').findall('item')
#      60
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\defusedxml\common.py in fromstring(text, forbid_dtd, forbid_entities, forbid_external)
#     126         parser.feed(text)
# --> 127         return parser.close()
#     128
#
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in close(self)
#    1728         except self._error as v:
# -> 1729             self._raiseerror(v)
#    1730         try:
#
# ~\AppData\Local\Programs\Python\Python39\lib\xml\etree\ElementTree.py in _raiseerror(self, value)
#    1628         err.position = value.lineno, value.offset
# -> 1629         raise err
#    1630
#
# ParseError: no element found: line 1, column 0
#
# During handling of the above exception, another exception occurred:
#
# SportError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_39172/939028886.py in <module>
# ----> 1 all_matches = sports.all_matches()
#       2 nfl = all_matches['football']
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in all_matches()
#     169     :rtype: dict
#     170     """
# --> 171     return {sport: get_sport(sport) for sport in constants.SPORTS}
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in <dictcomp>(.0)
#     169     :rtype: dict
#     170     """
# --> 171     return {sport: get_sport(sport) for sport in constants.SPORTS}
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in get_sport(sport)
#     104     """
#     105     sport = sport.lower()
# --> 106     data = _request_xml(sport)
#     107
#     108     cricket_regex = re.compile(r'\(([^)]+)\) #(.+) vs #(.+): ([\d/]+\s\([^)]+\))? ?- ([\d/]+\s\([^)]+\))?')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sports\scores.py in _request_xml(sport)
#      45         return _load_xml(r.content)
#      46     except ET.ParseError:
# ---> 47         raise errors.SportError(sport)
#      48
#      49
#
# SportError: Sport not found for baseball
